# %% [markdown]
# # Assessing
# Use the space below to explore `all_alpha_08.csv` and `all_alpha_18.csv` to answer the quiz questions below.

# %%
import pandas as pd

# %%
df_08 = pd.read_excel("all_alpha_08.xls")
df_18 = pd.read_excel("all_alpha_18.xlsx")

# %%
df_08
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df_18
# Out:
#            Model  Displ  Cyl       Trans Drive                  Fuel  \
# 0      ACURA ILX    2.4  4.0       AMS-8   2WD              Gasoline
# 1      ACURA ILX    2.4  4.0       AMS-8   2WD              Gasoline
# 2      ACURA MDX    3.0  6.0       AMS-7   4WD              Gasoline
# 3      ACURA MDX    3.0  6.0       AMS-7   4WD              Gasoline
# 4      ACURA MDX    3.5  6.0  SemiAuto-9   2WD              Gasoline
# ...          ...    ...  ...         ...   ...                   ...
# 2708  VOLVO XC90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 2709  VOLVO XC90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 2710  VOLVO XC90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 2711  VOLVO XC90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 2712  VOLVO XC90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert Region       Stnd            Stnd Description  Underhood ID  \
# ...

# %%
#duplicate rows in df 
df_08.duplicated().sum()
# Out:
# 25

# %%
df_08.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                      object
# Trans                    object
# Drive                    object
# Fuel                     object
# Sales Area               object
# Stnd                     object
# Underhood ID             object
# Veh Class                object
# Air Pollution Score      object
# FE Calc Appr             object
# City MPG                 object
# Hwy MPG                  object
# Cmb MPG                  object
# Unadj Cmb MPG           float64
# Greenhouse Gas Score     object
# SmartWay                 object
# dtype: object

# %%
df_18.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                     float64
# Trans                    object
# Drive                    object
# Fuel                     object
# Cert Region              object
# Stnd                     object
# Stnd Description         object
# Underhood ID             object
# Veh Class                object
# Air Pollution Score       int64
# City MPG                 object
# Hwy MPG                  object
# Cmb MPG                  object
# Greenhouse Gas Score      int64
# SmartWay                 object
# Comb CO2                 object
# dtype: object

# %%
#features/rows with missing values

df_08[df_08.isnull().any(axis=1)]
# Out:
#                        Model  Displ  Cyl Trans Drive      Fuel Sales Area  \
# 389   CHEVROLET Express 3500    6.0  NaN   NaN   NaN  Gasoline         FC
# 390   CHEVROLET Express 3500    6.2  NaN   NaN   NaN  Gasoline         FC
# 391   CHEVROLET Express 3500    4.8  NaN   NaN   NaN  Gasoline         FA
# 392   CHEVROLET Express 3500    4.8  NaN   NaN   NaN  Gasoline         FA
# 393   CHEVROLET Express 3500    4.8  NaN   NaN   NaN  Gasoline         CA
# ...                      ...    ...  ...   ...   ...       ...        ...
# 1465       LINCOLN Navigator    5.4  NaN   NaN   4WD  Gasoline         FA
# 1934     PORSCHE Cayenne GTS    4.8  NaN   NaN   4WD  Gasoline         CA
# 1935     PORSCHE Cayenne GTS    4.8  NaN   NaN   4WD  Gasoline         FA
# 1939   PORSCHE Cayenne Turbo    4.8  NaN   NaN   4WD  Gasoline         FA
# 1941   PORSCHE Cayenne Turbo    4.8  NaN   NaN   4WD  Gasoline         CA
#
#      Stnd  Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG  \
# ...

# %%
df_18[df_18.isnull().any(axis=1)]
# Out:
#                                      Model  Displ  Cyl   Trans Drive  \
# 357                          BMW i3 (94Ah)    NaN  NaN  Auto-1   2WD
# 358                          BMW i3 (94Ah)    NaN  NaN  Auto-1   2WD
# 361                         BMW i3s (94Ah)    NaN  NaN  Auto-1   2WD
# 362                         BMW i3s (94Ah)    NaN  NaN  Auto-1   2WD
# 397                                 BYD e6    NaN  NaN  Auto-1   2WD
# 450                      CHEVROLET Bolt EV    NaN  NaN  Auto-1   2WD
# 451                      CHEVROLET Bolt EV    NaN  NaN  Auto-1   2WD
# 748                              FIAT 500e    NaN  NaN  Auto-1   2WD
# 749                              FIAT 500e    NaN  NaN  Auto-1   2WD
# 893                    FORD Focus Electric    NaN  NaN  Auto-1   2WD
# 894                    FORD Focus Electric    NaN  NaN  Auto-1   2WD
# 1126                         HONDA Clarity    NaN  NaN  Auto-1   2WD
# 1127                         HONDA Clarity    NaN  NaN  Auto-1   2WD
# ...

# %%
#number of non-null unique values for features in each dataset
# count for unique values 
# nunique - NaN values are not included in the count

#df_08["SmartWay"].notnull().count()
df_08.nunique()
# Out:
# Model                   436
# Displ                    47
# Cyl                       8
# Trans                    14
# Drive                     2
# Fuel                      5
# Sales Area                3
# Stnd                     12
# Underhood ID            343
# Veh Class                 9
# Air Pollution Score      13
# FE Calc Appr              2
# City MPG                 39
# Hwy MPG                  43
# Cmb MPG                  38
# Unadj Cmb MPG           721
# Greenhouse Gas Score     20
# SmartWay                  2
# dtype: int64

# %%
df_18.notnull().count()
df_18.nunique()
# Out:
# Model                   652
# Displ                    45
# Cyl                       9
# Trans                    29
# Drive                     2
# Fuel                      6
# Cert Region               2
# Stnd                     25
# Stnd Description         25
# Underhood ID            422
# Veh Class                10
# Air Pollution Score       7
# City MPG                113
# Hwy MPG                 119
# Cmb MPG                 110
# Greenhouse Gas Score     10
# SmartWay                  3
# Comb CO2                404
# dtype: int64

# %% [markdown]
# #### Where are each of these fuel types present?
#
# Gasoline
# Ethanol/Gas
# Gasoline/Electricity
# CNG
# Electricity

# %%
def check_fuel_type(fuel):
    return {"08": len(df_08[df_08["Fuel"] == fuel]) > 0, "18": len(df_18[df_18["Fuel"] == fuel]) > 0}

# %%
#len(df_08[df_08["Fuel"] == "Gasoline"])
#len(df_08)
check_fuel_type("Gasoline")
# Out:
# {'08': True, '18': True}

# %%
check_fuel_type("Ethanol/Gas")
# Out:
# {'08': False, '18': True}

# %%
check_fuel_type("Gasoline/Electricity")
# Out:
# {'08': False, '18': True}

# %%
check_fuel_type("CNG")
# Out:
# {'08': True, '18': False}

# %%
check_fuel_type("Electricity")
# Out:
# {'08': False, '18': True}
