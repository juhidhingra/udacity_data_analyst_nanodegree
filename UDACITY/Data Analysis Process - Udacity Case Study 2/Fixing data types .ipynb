# %%
import pandas as pd

# %%
df_08 = pd.read_csv('data_08_v2.csv')
df_18 = pd.read_csv('data_18_v2.csv')

# %%
df_08.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                      object
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score      object
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score     object
# smartway                 object
# dtype: object

# %%
df_18.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                     float64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score       int64
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
# Extract int from strings in the 2008 cyl column

#https://stackoverflow.com/questions/35376387/extract-int-from-string-in-pandas

# + is 1 or more digits
# \d is a digit (a character in the range 0-9)
# \d+ means match 1 or more digits

# %%
## Check value counts for 2008 cyl column again to confirm the change
df_08['cyl'].value_counts()
# Out:
# (6 cyl)     646
# (4 cyl)     455
# (8 cyl)     392
# (5 cyl)     109
# (12 cyl)     30
# (10 cyl)     15
# (2 cyl)       2
# (16 cyl)      1
# Name: cyl, dtype: int64

# %%
df_08['cyl'] = df_08['cyl'].str.extract('(\d+)').astype(int)

# %%
# convert 2018 cyl column to int
df_18["cyl"] = df_18.cyl.astype(int)

# %%
df_08.to_csv('data_08_v3.csv', index=False)
df_18.to_csv('data_18_v3.csv', index=False)

# %%
df_08 = pd.read_csv('data_08_v3.csv')
df_18 = pd.read_csv('data_18_v3.csv')

# %%
df_08.shape
# Out:
# (1650, 13)

# %%
df_18.shape
# Out:
# (1361, 13)

# %% [markdown]
# Fixing air_pollution_score Data Type
#
# 2008: convert string to float
# 2018: convert int to float

# %%
# try using pandas' to_numeric or astype function to convert the
# 2008 air_pollution_score column to float -- this won't work

#df_08["air_pollution_score"] = df_08.air_pollution_score.astype(float)

# %% [markdown]
# Figuring out the issue
# Looks like this isn't going to be as simple as converting the datatype. According to the error above, the air pollution score value in one of the rows is "6/4" - let's check it out.
#
# df_08[df_08.air_pollution_score == '6/4']
# It's not just the air pollution score!
# The mpg columns and greenhouse gas scores also seem to have the same problem - maybe that's why these were all saved as strings! According to this link, which I found from the PDF documentation:https://www.fueleconomy.gov/feg/findacarhelp.shtml#airPollutionScore
#
# "If a vehicle can operate on more than one type of fuel, an estimate is provided for each fuel type."
# Ohh... so all vehicles with more than one fuel type, or hybrids, like the one above (it uses ethanol AND gas) will have a string that holds two values - one for each. This is a little tricky, so I'm going to show you how to do it with the 2008 dataset, and then you'll try it with the 2018 dataset.

# %%
df_08[df_08.air_pollution_score == '6/4']
# Out:
#                    model  displ  cyl    trans drive         fuel  veh_class  \
# 1022  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1022                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1022       no

# %%
# First, let's get all the hybrids in 2008
hb_08 = df_08[df_08['fuel'].str.contains('/')]
hb_08
# Out:
#                          model  displ  cyl    trans drive         fuel  \
# 209   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol/gas
# 210   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  ethanol/gas
# 214   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol/gas
# 215   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  ethanol/gas
# 262     CHEVROLET Express 1500    5.3    8  Auto-L4   4WD  ethanol/gas
# ...                        ...    ...  ...      ...   ...          ...
# 1149         MITSUBISHI Raider    4.7    8  Auto-L5   4WD  ethanol/gas
# 1175             NISSAN Armada    5.6    8  Auto-L5   2WD  ethanol/gas
# 1176             NISSAN Armada    5.6    8  Auto-L5   4WD  ethanol/gas
# 1211              NISSAN Titan    5.6    8  Auto-L5   2WD  ethanol/gas
# 1212              NISSAN Titan    5.6    8  Auto-L5   4WD  ethanol/gas
#
#      veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 209        SUV                 7/7    11/14   15/20   12/16
# 210        SUV                 7/7    11/14   14/19   12/16
# 214        SUV                 6/6    11/14   15/20   12/16
# 215        SUV                 6/6    11/14   14/19   12/16
# 262        van                 6/6     9/12   12/16   10/14
# ...        ...                 ...      ...     ...     ...
# 1149    pickup                 3/3     9/14   12/19   10/15
# 1175       SUV                 6/6     9/12   13/18   10/14
# 1176       SUV                 6/6     9/12   13/17   10/14
# 1211    pickup                 6/6     9/12   13/17   10/14
# 1212    pickup                 6/6     9/12   12/17   10/14
#
#      greenhouse_gas_score smartway
# 209                   6/4       no
# 210                   6/4       no
# 214                   6/4       no
# 215                   6/4       no
# 262                   4/2       no
# ...                   ...      ...
# 1149                  4/3       no
# 1175                  4/2       no
# 1176                  4/2       no
# 1211                  4/2       no
# 1212                  4/2       no
#
# [65 rows x 13 columns]

# %% [markdown]
# Looks like this dataset only has one! The 2018 has MANY more - but don't worry - the steps I'm taking here will work for that as well!

# %%
# hybrids in 2018
hb_18 = df_18[df_18['fuel'].str.contains('/')]
hb_18
# Out:
#                    model  displ  cyl       trans drive                  fuel  \
# 30        AUDI A3 e-tron    1.4    4       AMS-6   2WD  Gasoline/Electricity
# 88              BMW 330e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 114             BMW 530e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 115             BMW 530e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 130             BMW 740e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# ...                  ...    ...  ...         ...   ...                   ...
# 1285  TOYOTA Sequoia FFV    5.7    8  SemiAuto-6   4WD           Ethanol/Gas
# 1298   TOYOTA Tundra FFV    5.7    8  SemiAuto-6   4WD           Ethanol/Gas
# 1344           VOLVO S90    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 1356          VOLVO XC60    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 1360          VOLVO XC90    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
#
#          veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 30       small car                    7    34/81   39/86   36/83
# 88       small car                    3    28/66   34/78   30/71
# 114      small car                    7    27/70   31/75   29/72
# 115      small car                    7    27/66   31/68   28/67
# 130      large car                    3    25/62   29/68   27/64
# ...            ...                  ...      ...     ...     ...
# 1285  standard SUV                    5     9/13   13/17   10/14
# 1298        pickup                    5     9/13   12/17   10/15
# 1344   midsize car                    7    26/70   33/72   29/71
# 1356     small SUV                    7    26/60   28/58   26/59
# 1360  standard SUV                    7    26/63   30/61   27/62
#
#       greenhouse_gas_score smartway
# 30                      10    Elite
# 88                      10      Yes
# 114                     10    Elite
# 115                     10    Elite
# 130                      9      Yes
# ...                    ...      ...
# 1285                     1       No
# 1298                     2       No
# 1344                    10    Elite
# 1356                    10    Elite
# 1360                    10    Elite
#
# [89 rows x 13 columns]

# %% [markdown]
# We're going to take each hybrid row and split them into two new rows - one with values for the first fuel type (values before the "/"), and the other with values for the second fuel type (values after the "/"). Let's separate them with two dataframes!

# %%
# create two copies of the 2008 hybrids dataframe
df1 = hb_08.copy()  # data on first fuel type of each hybrid vehicle
df2 = hb_08.copy()  # data on second fuel type of each hybrid vehicle

# Each one should look like this
#df1

# %% [markdown]
# For this next part, we're going use pandas' apply function. See the docs https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html

# %%
# columns to split by "/"
split_columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']

# %%
# apply split function to each column of each dataframe copy

for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])

# %%
# this dataframe holds info for the FIRST fuel type of the hybrid
# aka the values before the "/"s

df1
# Out:
#                          model  displ  cyl    trans drive     fuel veh_class  \
# 209   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol       SUV
# 210   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  ethanol       SUV
# 214   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol       SUV
# 215   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  ethanol       SUV
# 262     CHEVROLET Express 1500    5.3    8  Auto-L4   4WD  ethanol       van
# ...                        ...    ...  ...      ...   ...      ...       ...
# 1149         MITSUBISHI Raider    4.7    8  Auto-L5   4WD  ethanol    pickup
# 1175             NISSAN Armada    5.6    8  Auto-L5   2WD  ethanol       SUV
# 1176             NISSAN Armada    5.6    8  Auto-L5   4WD  ethanol       SUV
# 1211              NISSAN Titan    5.6    8  Auto-L5   2WD  ethanol    pickup
# 1212              NISSAN Titan    5.6    8  Auto-L5   4WD  ethanol    pickup
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 209                    7       11      15      12                    6
# 210                    7       11      14      12                    6
# 214                    6       11      15      12                    6
# 215                    6       11      14      12                    6
# 262                    6        9      12      10                    4
# ...                  ...      ...     ...     ...                  ...
# 1149                   3        9      12      10                    4
# 1175                   6        9      13      10                    4
# 1176                   6        9      13      10                    4
# 1211                   6        9      13      10                    4
# 1212                   6        9      12      10                    4
#
#      smartway
# 209        no
# 210        no
# 214        no
# 215        no
# 262        no
# ...       ...
# 1149       no
# 1175       no
# 1176       no
# 1211       no
# 1212       no
#
# [65 rows x 13 columns]

# %%
# this dataframe holds info for the SECOND fuel type of the hybrid
# aka the values after the "/"s

df2
# Out:
#                          model  displ  cyl    trans drive fuel veh_class  \
# 209   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  gas       SUV
# 210   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  gas       SUV
# 214   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  gas       SUV
# 215   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  gas       SUV
# 262     CHEVROLET Express 1500    5.3    8  Auto-L4   4WD  gas       van
# ...                        ...    ...  ...      ...   ...  ...       ...
# 1149         MITSUBISHI Raider    4.7    8  Auto-L5   4WD  gas    pickup
# 1175             NISSAN Armada    5.6    8  Auto-L5   2WD  gas       SUV
# 1176             NISSAN Armada    5.6    8  Auto-L5   4WD  gas       SUV
# 1211              NISSAN Titan    5.6    8  Auto-L5   2WD  gas    pickup
# 1212              NISSAN Titan    5.6    8  Auto-L5   4WD  gas    pickup
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 209                    7       14      20      16                    4
# 210                    7       14      19      16                    4
# 214                    6       14      20      16                    4
# 215                    6       14      19      16                    4
# 262                    6       12      16      14                    2
# ...                  ...      ...     ...     ...                  ...
# 1149                   3       14      19      15                    3
# 1175                   6       12      18      14                    2
# 1176                   6       12      17      14                    2
# 1211                   6       12      17      14                    2
# 1212                   6       12      17      14                    2
#
#      smartway
# 209        no
# 210        no
# 214        no
# 215        no
# 262        no
# ...       ...
# 1149       no
# 1175       no
# 1176       no
# 1211       no
# 1212       no
#
# [65 rows x 13 columns]

# %%
# combine dataframes to add to the original dataframe
new_df = df1.append(df2)

# now we have separate rows for each fuel type of each vehicle!
new_df
# Out:
#                          model  displ  cyl    trans drive     fuel veh_class  \
# 209   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol       SUV
# 210   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  ethanol       SUV
# 214   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   2WD  ethanol       SUV
# 215   CHEVROLET Avalanche 1500    5.3    8  Auto-L4   4WD  ethanol       SUV
# 262     CHEVROLET Express 1500    5.3    8  Auto-L4   4WD  ethanol       van
# ...                        ...    ...  ...      ...   ...      ...       ...
# 1149         MITSUBISHI Raider    4.7    8  Auto-L5   4WD      gas    pickup
# 1175             NISSAN Armada    5.6    8  Auto-L5   2WD      gas       SUV
# 1176             NISSAN Armada    5.6    8  Auto-L5   4WD      gas       SUV
# 1211              NISSAN Titan    5.6    8  Auto-L5   2WD      gas    pickup
# 1212              NISSAN Titan    5.6    8  Auto-L5   4WD      gas    pickup
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 209                    7       11      15      12                    6
# 210                    7       11      14      12                    6
# 214                    6       11      15      12                    6
# 215                    6       11      14      12                    6
# 262                    6        9      12      10                    4
# ...                  ...      ...     ...     ...                  ...
# 1149                   3       14      19      15                    3
# 1175                   6       12      18      14                    2
# 1176                   6       12      17      14                    2
# 1211                   6       12      17      14                    2
# 1212                   6       12      17      14                    2
#
#      smartway
# 209        no
# 210        no
# 214        no
# 215        no
# 262        no
# ...       ...
# 1149       no
# 1175       no
# 1176       no
# 1211       no
# 1212       no
#
# [130 rows x 13 columns]

# %%
# add in our newly separated rows
df_08 = df_08.append(new_df, ignore_index=True)

# %%
df_08
# Out:
#                   model  displ  cyl    trans drive      fuel    veh_class  \
# 0             ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 1             ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 2             ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 3             ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 4              ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# ...                 ...    ...  ...      ...   ...       ...          ...
# 1775  MITSUBISHI Raider    4.7    8  Auto-L5   4WD       gas       pickup
# 1776      NISSAN Armada    5.6    8  Auto-L5   2WD       gas          SUV
# 1777      NISSAN Armada    5.6    8  Auto-L5   4WD       gas          SUV
# 1778       NISSAN Titan    5.6    8  Auto-L5   2WD       gas       pickup
# 1779       NISSAN Titan    5.6    8  Auto-L5   4WD       gas       pickup
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 0                      7       15      20      17                    4
# 1                      6       15      20      17                    4
# 2                      7       17      22      19                    5
# 3                      6       17      22      19                    5
# 4                      7       16      24      19                    5
# ...                  ...      ...     ...     ...                  ...
# 1775                   3       14      19      15                    3
# 1776                   6       12      18      14                    2
# 1777                   6       12      17      14                    2
# 1778                   6       12      17      14                    2
# 1779                   6       12      17      14                    2
#
#      smartway
# 0          no
# 1          no
# 2          no
# 3          no
# 4          no
# ...       ...
# 1775       no
# 1776       no
# 1777       no
# 1778       no
# 1779       no
#
# [1780 rows x 13 columns]

# %%
df_08.tail(3)
# Out:
#               model  displ  cyl    trans drive fuel veh_class  \
# 1777  NISSAN Armada    5.6    8  Auto-L5   4WD  gas       SUV
# 1778   NISSAN Titan    5.6    8  Auto-L5   2WD  gas    pickup
# 1779   NISSAN Titan    5.6    8  Auto-L5   4WD  gas    pickup
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1777                   6       12      17      14                    2
# 1778                   6       12      17      14                    2
# 1779                   6       12      17      14                    2
#
#      smartway
# 1777       no
# 1778       no
# 1779       no

# %%
# drop the original hybrid rows
df_08.drop(hb_08.index, inplace=True)

# %%
# check that all the original hybrid rows with "/"s are gone
df_08[df_08['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# hybrids in 2018
hb_18 = df_18[df_18['fuel'].str.contains('/')]
hb_18
# Out:
#                    model  displ  cyl       trans drive                  fuel  \
# 30        AUDI A3 e-tron    1.4    4       AMS-6   2WD  Gasoline/Electricity
# 88              BMW 330e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 114             BMW 530e    2.0    4  SemiAuto-8   2WD  Gasoline/Electricity
# 115             BMW 530e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 130             BMW 740e    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# ...                  ...    ...  ...         ...   ...                   ...
# 1285  TOYOTA Sequoia FFV    5.7    8  SemiAuto-6   4WD           Ethanol/Gas
# 1298   TOYOTA Tundra FFV    5.7    8  SemiAuto-6   4WD           Ethanol/Gas
# 1344           VOLVO S90    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 1356          VOLVO XC60    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 1360          VOLVO XC90    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
#
#          veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 30       small car                    7    34/81   39/86   36/83
# 88       small car                    3    28/66   34/78   30/71
# 114      small car                    7    27/70   31/75   29/72
# 115      small car                    7    27/66   31/68   28/67
# 130      large car                    3    25/62   29/68   27/64
# ...            ...                  ...      ...     ...     ...
# 1285  standard SUV                    5     9/13   13/17   10/14
# 1298        pickup                    5     9/13   12/17   10/15
# 1344   midsize car                    7    26/70   33/72   29/71
# 1356     small SUV                    7    26/60   28/58   26/59
# 1360  standard SUV                    7    26/63   30/61   27/62
#
#       greenhouse_gas_score smartway
# 30                      10    Elite
# 88                      10      Yes
# 114                     10    Elite
# 115                     10    Elite
# 130                      9      Yes
# ...                    ...      ...
# 1285                     1       No
# 1298                     2       No
# 1344                    10    Elite
# 1356                    10    Elite
# 1360                    10    Elite
#
# [89 rows x 13 columns]

# %%
# create two copies of the 2018 hybrids dataframe
df3 = hb_18.copy()  # data on first fuel type of each hybrid vehicle
df4 = hb_18.copy()  # data on second fuel type of each hybrid vehicle

# Each one should look like this
#df3

# %%
# columns to split by "/"
#Split values for fuel, city_mpg, hwy_mpg, cmb_mpg
#You don't need to split for air_pollution_score or greenhouse_gas_score here because these columns are already ints in the 2018 dataset.

split_columns = ['fuel', 'city_mpg', 'hwy_mpg', 'cmb_mpg']

# %%
df3.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score       int64
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
# apply split function to each column of each dataframe copy

for c in split_columns:
    df3[c] = df3[c].apply(lambda x: x.split("/")[0])
    df4[c] = df4[c].apply(lambda x: x.split("/")[1])

# %%
# combine dataframes to add to the original dataframe
new_df_18 = df3.append(df4)

# now we have separate rows for each fuel type of each vehicle!
new_df_18
# Out:
#                    model  displ  cyl       trans drive         fuel  \
# 30        AUDI A3 e-tron    1.4    4       AMS-6   2WD     Gasoline
# 88              BMW 330e    2.0    4  SemiAuto-8   2WD     Gasoline
# 114             BMW 530e    2.0    4  SemiAuto-8   2WD     Gasoline
# 115             BMW 530e    2.0    4  SemiAuto-8   4WD     Gasoline
# 130             BMW 740e    2.0    4  SemiAuto-8   4WD     Gasoline
# ...                  ...    ...  ...         ...   ...          ...
# 1285  TOYOTA Sequoia FFV    5.7    8  SemiAuto-6   4WD          Gas
# 1298   TOYOTA Tundra FFV    5.7    8  SemiAuto-6   4WD          Gas
# 1344           VOLVO S90    2.0    4  SemiAuto-8   4WD  Electricity
# 1356          VOLVO XC60    2.0    4  SemiAuto-8   4WD  Electricity
# 1360          VOLVO XC90    2.0    4  SemiAuto-8   4WD  Electricity
#
#          veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 30       small car                    7       34      39      36
# 88       small car                    3       28      34      30
# 114      small car                    7       27      31      29
# 115      small car                    7       27      31      28
# 130      large car                    3       25      29      27
# ...            ...                  ...      ...     ...     ...
# 1285  standard SUV                    5       13      17      14
# 1298        pickup                    5       13      17      15
# 1344   midsize car                    7       70      72      71
# 1356     small SUV                    7       60      58      59
# 1360  standard SUV                    7       63      61      62
#
#       greenhouse_gas_score smartway
# 30                      10    Elite
# 88                      10      Yes
# 114                     10    Elite
# 115                     10    Elite
# 130                      9      Yes
# ...                    ...      ...
# 1285                     1       No
# 1298                     2       No
# 1344                    10    Elite
# 1356                    10    Elite
# 1360                    10    Elite
#
# [178 rows x 13 columns]

# %%
# add in our newly separated rows
df_18 = df_18.append(new_df_18, ignore_index=True)

# %%
# drop the original hybrid rows
df_18.drop(hb_18.index, inplace=True)

# %%
# check that all the original hybrid rows with "/"s are gone
df_18[df_18['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %% [markdown]
# Now we can comfortably continue the changes needed for air_pollution_score! Here they are again:
# 2008: convert string to float
# 2018: convert int to float

# %%
def change_type_from_string(df, col_name, dtype):
    return df[col_name].str.extract('(\d+)').astype(dtype)

# %%
def change_type(df, col_name, dtype):
    return df[col_name].astype(dtype)

# %%
df_08["air_pollution_score"] = change_type_from_string(df_08,"air_pollution_score",float)

# %%
df_18["air_pollution_score"] = change_type(df_18,"air_pollution_score",float)

# %%
#Fix city_mpg, hwy_mpg, cmb_mpg datatypes

#2008 and 2018: convert string to float

df_08["city_mpg"] = change_type_from_string(df_08,"city_mpg",float)

# %%
df_18["city_mpg"] = change_type_from_string(df_18,"city_mpg",float)

# %%
df_08["hwy_mpg"] = change_type_from_string(df_08,"hwy_mpg",float)

# %%
df_18["hwy_mpg"] = change_type_from_string(df_18,"hwy_mpg",float)

# %%
df_08["cmb_mpg"] = change_type_from_string(df_08,"cmb_mpg",float)

# %%
df_18["cmb_mpg"] = change_type_from_string(df_18,"cmb_mpg",float)

# %%
#Fix greenhouse_gas_score datatype

df_08["greenhouse_gas_score"] = change_type_from_string(df_08,"greenhouse_gas_score",int)

# %%
df_08.shape
# Out:
# (1715, 13)

# %%
df_18.shape
# Out:
# (1450, 13)

# %%
df_08.to_csv('data_08_v4.csv', index=False)
df_18.to_csv('data_18_v4.csv', index=False)

# %%
# load datasets

df_08 = pd.read_csv('data_08_v4.csv')
df_18 = pd.read_csv('data_18_v4.csv')
